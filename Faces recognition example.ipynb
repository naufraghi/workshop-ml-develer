# %% [markdown]
# # Faces recognition example
#
# Adapted from [scikit-learn/examples/face_recognition.html](http://scikit-learn.org/stable/auto_examples/applications/face_recognition.html)

# %%
from __future__ import print_function

from time import time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.cross_validation import train_test_split
from sklearn.datasets import fetch_lfw_people
from sklearn.grid_search import GridSearchCV
from sklearn import metrics
from sklearn.decomposition import RandomizedPCA
from sklearn.svm import SVC

# %% [markdown]
# The dataset used in this example is a preprocessed excerpt of the “Labeled Faces in the Wild”, aka LFW [lfw-funneled.tgz](http://vis-www.cs.umass.edu/lfw/lfw-funneled.tgz) (233MB), it will be downloaded, so the next cell may
# take a while to execute.

# %%
###############################################################################
# Download the data, if not already on disk and load it as numpy arrays

lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=0.4)

# introspect the images arrays to find the shapes (for plotting)
n_samples, h, w = lfw_people.images.shape

# for machine learning we use the `data` directly (as relative pixel
# positions info is ignored by this model)
X = lfw_people.data
n_features = X.shape[1]

# the label to predict is the id of the person
y = lfw_people.target
target_names = lfw_people.target_names
n_classes = len(target_names)

print("Total dataset sizes")
print("n_samples: %d" % n_samples)
print("n_features: %d" % n_features)
print("n_classes: %d" % n_classes)
# Out:
# Total dataset sizes
# n_samples: 1288
# n_features: 1850
# n_classes: 7

# %% [markdown]
# Let's visualize these faces to see what we're working with:

# %%
fig = plt.figure(figsize=(8, 6))
# plot several images
for i in range(15):
    ax = fig.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    ax.imshow(lfw_people.images[i], cmap=plt.cm.bone)

# %%
plt.figure(figsize=(10, 2))

unique_targets = np.unique(lfw_people.target)
counts = [(lfw_people.target == i).sum() for i in unique_targets]

plt.xticks(unique_targets, lfw_people.target_names[unique_targets])
locs, labels = plt.xticks()
plt.setp(labels, rotation=45, size=14)
plt.bar(unique_targets, counts);

# %%
###############################################################################
# Split into a training set and a test set using a stratified k fold

# split into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

# %% [markdown]
# ## Preprocessing: Principal Component Analysis
#
# 1850 dimensions is a lot for SVM.  We can use PCA to reduce these 1850 features to a manageable
# size, while maintaining most of the information in the dataset.  Here it is useful to use a variant
# of PCA called ``RandomizedPCA``, which is an approximation of PCA that can be much faster for large
# datasets.  The interface is the same as the normal PCA we saw earlier:

# %%
###############################################################################
# Compute a PCA (eigenfaces) on the face dataset (treated as unlabeled
# dataset): unsupervised feature extraction / dimensionality reduction
n_components = 150

print("Extracting the top %d eigenfaces from %d faces"
      % (n_components, X_train.shape[0]))
t0 = time()
pca = RandomizedPCA(n_components=n_components, whiten=True, random_state=123).fit(X_train)
print("done in %0.3fs" % (time() - t0))

eigenfaces = pca.components_.reshape((n_components, h, w))

print("Projecting the input data on the eigenfaces orthonormal basis")
t0 = time()
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)
print("done in %0.3fs" % (time() - t0))
# Out:
# Extracting the top 150 eigenfaces from 966 faces
# done in 1.491s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.163s

# %%
###############################################################################
# Qualitative evaluation of the predictions using matplotlib

def plot_gallery(images, titles, h, w, n_row=3, n_col=4):
    """Helper function to plot a gallery of portraits"""
    plt.figure(figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_row * n_col):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i].reshape((h, w)), cmap=plt.cm.gray)
        plt.title(titles[i], size=12)
        plt.xticks(())
        plt.yticks(())

# %%
# plot the gallery of the most significative eigenfaces

eigenface_titles = ["eigenface %d" % i for i in range(eigenfaces.shape[0])]
plot_gallery(eigenfaces, eigenface_titles, h, w)

plt.show()

# %% [markdown]
# The components ("eigenfaces") are ordered by their importance from top-left to bottom-right.
# We see that the first few components seem to primarily take care of lighting
# conditions; the remaining components pull out certain identifying features:
# the nose, eyes, eyebrows, etc.

# %%
###############################################################################
# Train a SVM classification model

print("Fitting the classifier to the training set")
clf = SVC(C=1, gamma=0.01, kernel='rbf', class_weight='auto')
clf = clf.fit(X_train_pca, y_train)
# Out:
# Fitting the classifier to the training set

# %%
###############################################################################
# Quantitative evaluation of the model quality on the test set

print("Predicting people's names on the test set")
y_pred = clf.predict(X_test_pca)

print("accuracy:", metrics.accuracy_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Predicting people's names on the test set
# accuracy:
#  0.788819875776
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       1.00      0.33      0.50        15
#      Colin Powell       0.51      1.00      0.68        55
#   Donald Rumsfeld       0.96      0.63      0.76        43
#     George W Bush       0.92      0.81      0.86       135
# Gerhard Schroeder       0.88      0.96      0.92        24
#       Hugo Chavez       1.00      0.47      0.64        17
#        Tony Blair       0.93      0.82      0.87        33
#
#       avg / total       0.86      0.79      0.79       322

# %% [markdown]
# ### Note on the meaning of these terms:
#
# **Accuracy**  is the number of correct guess over the number of samples
#
# $$
# {\rm accuracy} \equiv \frac{\rm correct~labels}{\rm total~samples}
# $$
#
# **Precision** is the number of correct guess over the number of tries
#
# $$
# {\rm precision} \equiv \frac{\rm true~positives}{\rm true~positives + false~positives}
# $$
#
# **Recall** is the number of correct guess over the number of targets to guess
#
# $$
# {\rm recall} \equiv \frac{\rm true~positives}{\rm true~positives + false~negatives}
# $$
#
# **$F_1$** score is the standard whay to have a single value from *Precision* and *Recall* scores
#
# $$ F_1 \equiv 2 \cdot \frac{\rm precision \cdot recall}{\rm precision + recall}
# $$
#
# For a simple explanatory example [Precision, Recall and F1 score (information retrieval)](http://www.slug.it/naufraghi/ingegneria/precision-recall-and-f1-score-information-retrieval/)

# %% [markdown]
# Il modello `SVC` ha vari parametri, e questi influiscono sulla qualità della predizione.
# Un modo per scegliere i gli *iperparametri* migliori (si considerano *parametri* del modello i pesi che apprende internamente) vengono solitamente calcolati su un dataset di validazione.
# Non è saggio scegliere gli iperparametri direttamente sul dataset di test, perché come per i parametri, c'è sempre il rischio di overfitting, in pratica di illudersi di essere più bravi di quanto potremo mai dimostrare su degli esempi mai visti prima.

# %%
###############################################################################
# Train a SVM classification model
from sklearn import cross_validation

print("Fitting the classifier to the training set")
t0 = time()
param_grid = {'C': [1e3, 5e3, 1e4, 5e4, 1e5],
              'gamma': [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.1], }
kfold = cross_validation.KFold(len(X_train_pca), random_state=123)
clf = GridSearchCV(SVC(kernel='rbf', class_weight='auto'), param_grid, cv=kfold)
clf = clf.fit(X_train_pca, y_train)
print("done in %0.3fs" % (time() - t0))
print("Best estimator found by grid search:")
print(clf.best_estimator_)

# %%
###############################################################################
# Quantitative evaluation of the model quality on the test set

print("Predicting people's names on the test set")
t0 = time()
y_pred = clf.predict(X_test_pca)
print("done in %0.3fs" % (time() - t0))

print("accuracy:", metrics.accuracy_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred, target_names=target_names))

# %% [markdown]
# Another interesting metric is the *confusion matrix*, which indicates how often
# any two items are mixed-up.  The confusion matrix of a perfect classifier
# would only have nonzero entries on the diagonal, with zeros on the off-diagonal.

# %%
print(metrics.confusion_matrix(y_test, y_pred, labels=range(n_classes)))

# %%
# plot the result of the prediction on a portion of the test set

def title(y_pred, y_test, target_names, i):
    pred_name = target_names[y_pred[i]].rsplit(' ', 1)[-1]
    true_name = target_names[y_test[i]].rsplit(' ', 1)[-1]
    return 'predicted: %s\ntrue:      %s' % (pred_name, true_name)

prediction_titles = [title(y_pred, y_test, target_names, i)
                     for i in range(y_pred.shape[0])]

plot_gallery(X_test, prediction_titles, h, w)

# %% [markdown]
# # E ora?
#
# Ci sono numerosi archivi di dataset per il machine learning, però uno dei più interessanti è sicuramente [Kaggle](https://www.kaggle.com/). Vi consiglio di farvi un account per mettervi alla prova, spesso l'oracolo che valuta la qualità della previsione resta acceso anche dopo la conclusione della competizione.
